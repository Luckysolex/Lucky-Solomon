# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def load_data(path):
    try:
        df = pd.read_csv(path)
        print("Data Loaded Successfully")
        return df
    except Exception as e:
        print(f"Error: {e}")
        return None

# %%
def generate_report(df):
    print("\n--- Dataset Overview ---")
    print(f"Rows: {df.shape[0]} | Columns: {df.shape[1]}")

    print("\n--- Missing Values ---")
    print(df.isnull().sum())

    print("\n--- Statistical Summary ---")
    print(df.describe())

# %%
def quick_plot(df):
    # Automatically plot correlation for numeric columns
    numeric_df = df.select_dtypes(include = ['number'])

    if not numeric_df.empty:
        plt.figure(figsize = (10, 6))
        sns.heatmap(numeric_df.corr(), annot = True, cmap = 'coolwarm')
        plt.title("Correlation Heatmap")
        plt.show()
    else:
        print("No Numeric Data Available for Correlation")

# %%
# Main Execution
path = input("Enter the path to your CSV file: ")
data = load_data(path)

if data is not None:
    generate_report(data)
    if input("\nGenerate Correlation Heatmap? (y/n): ").lower() == 'y':
        quick_plot(data)
# Out:
# Enter the path to your CSV file:  /Users/mac/Downloads/Titanic-Dataset.csv
# Data Loaded Successfully
#
# --- Dataset Overview ---
# Rows: 891 | Columns: 12
#
# --- Missing Values ---
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64
#
# --- Statistical Summary ---
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
# Generate Correlation Heatmap? (y/n):  y
